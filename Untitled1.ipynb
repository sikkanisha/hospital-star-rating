# %% [markdown]
# <a href="https://colab.research.google.com/github/sikkanisha/hospital-star-rating/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_csv("/HCAHPS-Hospital.csv",engine='python')

# %%
print(data.head(10))
# Out:
#   Facility ID                    Facility Name                 Address  \
# 0      010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1      010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 2      010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 3      010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 4      010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 5      010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 6      010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 7      010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 8      010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 9      010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#      City State  ZIP Code County Name    Phone Number      HCAHPS Measure ID  \
# 0  DOTHAN    AL   36301.0     HOUSTON  (334) 793-8701           H_COMP_1_A_P
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print('Rows :', data.shape[0])
print('Columns :', data.shape[1])
# Out:
# Rows : 12586
# Columns : 22

# %%
data.columns
# Out:
# Index(['Facility ID', 'Facility Name', 'Address', 'City', 'State', 'ZIP Code',
#        'County Name', 'Phone Number', 'HCAHPS Measure ID', 'HCAHPS Question',
#        'HCAHPS Answer Description', 'Patient Survey Star Rating',
#        'Patient Survey Star Rating Footnote', 'HCAHPS Answer Percent',
#        'HCAHPS Answer Percent Footnote', 'HCAHPS Linear Mean Value',
#        'Number of Completed Surveys', 'Number of Completed Surveys Footnote',
#        'Survey Response Rate Percent', 'Survey Response Rate Percent Footnote',
#        'Start Date', 'End Date'],
#       dtype='object')

# %%
  data.describe()
# Out:
#            ZIP Code  Patient Survey Star Rating Footnote  \
# count  12585.000000                           473.000000
# mean   54237.070083                            13.860465
# std    26925.619620                             4.438084
# min    35007.000000                             5.000000
# 25%    35660.000000                            15.000000
# 50%    36451.000000                            15.000000
# 75%    85351.000000                            15.000000
# max    99929.000000                            28.000000
#
#        HCAHPS Answer Percent Footnote  Number of Completed Surveys Footnote  \
# count                     3096.000000                           3999.000000
# mean                         5.555233                              6.930233
# std                          5.458155                              5.267472
# min                          1.000000                              1.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12586 entries, 0 to 12585
# Data columns (total 22 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Facility ID                            12586 non-null  object
#  1   Facility Name                          12586 non-null  object
#  2   Address                                12586 non-null  object
#  3   City                                   12585 non-null  object
#  4   State                                  12585 non-null  object
#  5   ZIP Code                               12585 non-null  float64
#  6   County Name                            12585 non-null  object
#  7   Phone Number                           12585 non-null  object
#  8   HCAHPS Measure ID                      12585 non-null  object
#  9   HCAHPS Question                        12585 non-null  object
# ...

# %%
data.isnull().sum()
# Out:
# Facility ID                                  0
# Facility Name                                0
# Address                                      0
# City                                         1
# State                                        1
# ZIP Code                                     1
# County Name                                  1
# Phone Number                                 1
# HCAHPS Measure ID                            1
# HCAHPS Question                              1
# HCAHPS Answer Description                    1
# Patient Survey Star Rating                   1
# Patient Survey Star Rating Footnote      12113
# HCAHPS Answer Percent                        1
# HCAHPS Answer Percent Footnote            9490
# HCAHPS Linear Mean Value                     1
# Number of Completed Surveys                  1
# Number of Completed Surveys Footnote      8587
# Survey Response Rate Percent                 1
# Survey Response Rate Percent Footnote     8587
# ...

# %%
df=data[data['HCAHPS Question']=='Overall hospital rating - star rating']

# %%
df.head()
# Out:
#     Facility ID                    Facility Name                     Address  \
# 86       010001  SOUTHEAST HEALTH MEDICAL CENTER      1108 ROSS CLARK CIRCLE
# 179      010005         MARSHALL MEDICAL CENTERS  2505 U S HIGHWAY 431 NORTH
# 272      010006     NORTH ALABAMA MEDICAL CENTER         1701 VETERANS DRIVE
# 365      010007         MIZELL MEMORIAL HOSPITAL               702 N MAIN ST
# 458      010008      CRENSHAW COMMUNITY HOSPITAL         101 HOSPITAL CIRCLE
#
#          City State  ZIP Code County Name    Phone Number  \
# 86     DOTHAN    AL   36301.0     HOUSTON  (334) 793-8701
# 179      BOAZ    AL   35957.0    MARSHALL  (256) 593-8310
# 272  FLORENCE    AL   35630.0  LAUDERDALE  (256) 768-8400
# 365       OPP    AL   36467.0   COVINGTON  (334) 493-3541
# 458   LUVERNE    AL   36049.0    CRENSHAW  (334) 335-3374
#
#             HCAHPS Measure ID                        HCAHPS Question  ...  \
# 86   H_HSP_RATING_STAR_RATING  Overall hospital rating - star rating  ...
# ...

# %%
#df[['Facility ID']].duplicates()
# Out:
# 135
# 22

# %%
sns.countplot(x=df['Patient Survey Star Rating'],data=df)
# Out:
# <Axes: xlabel='Patient Survey Star Rating', ylabel='count'>
